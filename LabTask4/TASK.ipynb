# %%
def check_luhn(card_number):
    card_number = card_number[::-1]  
    total = 0

    for i in range(len(card_number)):
        digit = int(card_number[i])
        if i % 2 == 1: 
            digit = digit * 2
            if digit > 9:
                digit = digit - 9
        total += digit

    if total % 10 == 0:
        print("Valid card number")
    else:
        print("Invalid card number")


num = input("Enter card number: ")
check_luhn(num)
# Out:
# Invalid card number

# %%
def remove_punctuation(text):
    punctuations = '''!()-[]{};:'"\,<>./?@#$%^&*_~'''
    result = ""

    for char in text:
        if char not in punctuations:
            result += char
    print("Without punctuation:", result)


text = input("Enter a sentence: ")
remove_punctuation(text)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\,'
# <>:2: SyntaxWarning: invalid escape sequence '\,'
# C:\Users\user1\AppData\Local\Temp\ipykernel_2332\2877372550.py:2: SyntaxWarning: invalid escape sequence '\,'
#   punctuations = '''!()-[]{};:'"\,<>./?@#$%^&*_~'''
# Without punctuation: hello how are you

# %%
def sort_sentence(text):
    words = text.split()       
    words.sort()              
    print("Sorted sentence:", ' '.join(words))


sentence = input("Enter a sentence: ")
sort_sentence(sentence)
# Out:
# Sorted sentence: How are hello you
